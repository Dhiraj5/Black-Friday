# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
RawData=pd.read_csv("AnalyticsVidhya/BlackFriday/train.csv")

sns.set(style="whitegrid", color_codes=True)
plt.clf()
#sns.stripplot(x="Gender", y="Purchase", data=RawData)
#sns.boxplot(x="Age", y="Purchase", data=RawData)
#sns.stripplot(x="Occupation", y="Purchase", data=RawData)
#sns.boxplot(x="City_Category", y="Purchase", data=RawData)
#sns.stripplot(x="Stay_In_Current_City_Years", y="Purchase", data=RawData)
#sns.boxplot(x="Marital_Status", y="Purchase", data=RawData)
#sns.boxplot(x="Product_Category_1", y="Purchase", data=RawData)
sns.boxplot(x="Product_Category_2", y="Purchase", data=RawData)
#sns.boxplot(x="Product_Category_3", y="Purchase", data=RawData)
sns.plt.show()
